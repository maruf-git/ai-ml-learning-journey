# %%
import pandas as pd

# %%
data = [["maruf",90],["rifat",70],["shifat",80]]
print(data)
print(type(data))
# Out:
# [['maruf', 90], ['rifat', '70'], ['shifat', 80]]
# <class 'list'>

# %%
df = pd.DataFrame(data,columns=["Name","Marks"])
print(df)
print(type(df))
# Out:
#      Name Marks
# 0   maruf    90
# 1   rifat    70
# 2  shifat    80
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df["Name"])  
print(type(df["Name"]))  
print(df["Marks"])
print(type(df["Marks"]))
# Out:
# 0     maruf
# 1     rifat
# 2    shifat
# Name: Name, dtype: object
# <class 'pandas.core.series.Series'>
# 0    90
# 1    70
# 2    80
# Name: Marks, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# We can made data frames from:
# 1. excel file
# 2. csv file
# 3. json file
# 4. url
